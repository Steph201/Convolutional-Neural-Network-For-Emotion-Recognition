# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
# %matplotlib inline
import tensorflow as tf
import keras 
import cv2
import warnings
warnings.simplefilter('ignore')

# %%
import os
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import Conv2D,Input,MaxPooling2D,Flatten,Activation,BatchNormalization,Dense,Dropout,AveragePooling2D

# %%
#Import and unzip files

#import zipfile
#with zipfile.ZipFile('Dataset_Emotion_Recognition.zip', 'r') as zip_ref:
#    zip_ref.extractall('Data1')

# %%
train_dir=r"Data/data/train"
train_dir
# Out:
# 'Data/data/train'

# %%
train_set=ImageDataGenerator(rotation_range=15,
                            rescale=1./255,
                              shear_range=0.2,
                            zoom_range=0.1,
                            width_shift_range=0.1,
                            height_shift_range=0.1)
train_gen=train_set.flow_from_directory(train_dir,target_size=(48,48),shuffle=True,class_mode='categorical',batch_size=64,color_mode='grayscale')
# Out:
# Found 28820 images belonging to 7 classes.

# %%
train_images,train_labels=next(train_gen)

# %%
train_images.shape
# Out:
# (64, 48, 48, 1)

# %%
train_labels.shape
# Out:
# (64, 7)

# %%
label_names={0:'angry',1:'disgust',2:'fear',3:'happy',4:'neutral',5:'sad',6:'surprise'}

# %%
l=8
w=8
fig,axes=plt.subplots(l,w,figsize=(16,12))
axes=axes.ravel()

for i in np.arange(0,l*w):
    axes[i].imshow(train_images[i])
    axes[i].set_title(label_names[np.argmax(train_labels[i])])
    axes[i].axis('off')
    
    plt.subplots_adjust(wspace=0.5)

# %%
model=Sequential()
model.add(Conv2D(64,(3,3),activation='relu',padding='same',input_shape=(48,48,1)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.25))
model.add(Conv2D(128,(3,3),activation='relu',padding='same'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.25))
model.add(Conv2D(256,(3,3),activation='relu',padding='same'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.25))
model.add(Conv2D(512,(3,3),activation='relu',padding='same'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.25))
model.add(Dense(64,activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.25))
model.add(Dense(7,activation='softmax'))

model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
train_set=ImageDataGenerator(rotation_range=15,
                            rescale=1./255,
                              shear_range=0.2,
                            zoom_range=0.1,
                            width_shift_range=0.1,
                            height_shift_range=0.1)
train_gen=train_set.flow_from_directory(train_dir,target_size=(48,48),shuffle=True,class_mode='categorical',batch_size=64,color_mode='grayscale')
# Out:
# Found 28820 images belonging to 7 classes.

# %%
test_dir=r"Data/data/test"
test_set=ImageDataGenerator(rotation_range=15,
                            rescale=1./255,
                            shear_range=0.2,
                             zoom_range=0.1,
                             width_shift_range=0.1,
                             height_shift_range=0.1)
valid_gen=test_set.flow_from_directory(test_dir,target_size=(48,48),shuffle=True,class_mode='categorical',batch_size=64,color_mode='grayscale')
# Out:
# Found 7066 images belonging to 7 classes.

# %%
from tensorflow.keras.callbacks import EarlyStopping,ReduceLROnPlateau
early_stop=EarlyStopping(monitor='val_loss',patience=2)
lr=ReduceLROnPlateau(monitor='val_loss',factor=0.1,patience=2,min_delta=0.0001)
callback=[early_stop,lr]

# %%
h1=model.fit_generator(train_gen,steps_per_epoch=(28820//64),epochs=10,validation_data=valid_gen,validation_steps=(7066//64),callbacks=callback)
# Out:
# Epoch 1/10
# 450/450 [==============================] - 459s 1s/step - loss: 1.9775 - accuracy: 0.2348 - val_loss: 1.7444 - val_accuracy: 0.2983 - lr: 0.0010
# Epoch 2/10
# 450/450 [==============================] - 441s 980ms/step - loss: 1.6330 - accuracy: 0.3651 - val_loss: 1.7058 - val_accuracy: 0.3567 - lr: 0.0010
# Epoch 3/10
# 450/450 [==============================] - 441s 980ms/step - loss: 1.4486 - accuracy: 0.4428 - val_loss: 1.5319 - val_accuracy: 0.4139 - lr: 0.0010
# Epoch 4/10
# 450/450 [==============================] - 438s 973ms/step - loss: 1.3519 - accuracy: 0.4816 - val_loss: 1.3232 - val_accuracy: 0.4922 - lr: 0.0010
# Epoch 5/10
# 450/450 [==============================] - 437s 972ms/step - loss: 1.2956 - accuracy: 0.5074 - val_loss: 1.2451 - val_accuracy: 0.5241 - lr: 0.0010
# Epoch 6/10
# 450/450 [==============================] - 437s 971ms/step - loss: 1.2568 - accuracy: 0.5200 - val_loss: 1.4270 - val_accuracy: 0.4634 - lr: 0.0010
# Epoch 7/10
# 450/450 [==============================] - 434s 963ms/step - loss: 1.2200 - accuracy: 0.5395 - val_loss: 1.2448 - val_accuracy: 0.5334 - lr: 0.0010
# Epoch 8/10
# 450/450 [==============================] - 434s 964ms/step - loss: 1.1960 - accuracy: 0.5472 - val_loss: 1.2819 - val_accuracy: 0.5178 - lr: 0.0010
# Epoch 9/10
# 450/450 [==============================] - 438s 973ms/step - loss: 1.1733 - accuracy: 0.5576 - val_loss: 1.1941 - val_accuracy: 0.5533 - lr: 0.0010
# Epoch 10/10
# 450/450 [==============================] - 433s 963ms/step - loss: 1.1536 - accuracy: 0.5649 - val_loss: 1.2031 - val_accuracy: 0.5337 - lr: 0.0010

# %%
h1.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
plt.figure(figsize=(12,8))
plt.title('Loss Evaluation')
plt.subplot(2,2,1)
plt.plot(h1.history['loss'],label='Loss')
plt.plot(h1.history['val_loss'],label='Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Training Loss')
plt.legend()

plt.title('Accuracy')
plt.subplot(2,2,2)
plt.plot(h1.history['accuracy'],label='Accuracy')
plt.plot(h1.history['val_accuracy'],label='Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Training Accuracy')
plt.legend()
plt.show()

# %%
test_dir=r"Data/data/test"
test_set=ImageDataGenerator(rotation_range=15,
                            rescale=1./255,
                            shear_range=0.2,
                             zoom_range=0.1,
                             width_shift_range=0.1,
                             height_shift_range=0.1)
test_gen=test_set.flow_from_directory(test_dir,target_size=(48,48),shuffle=True,class_mode='categorical',batch_size=64,color_mode='grayscale')
# Out:
# Found 7066 images belonging to 7 classes.

# %%
evaluate=model.evaluate_generator(test_gen,steps=(7066//64),verbose=1)
# Out:
# 110/110 [==============================] - 22s 197ms/step - loss: 1.2081 - accuracy: 0.5339

# %%
print('Accuracy during test {}'.format(evaluate[1]))
# Out:
# Accuracy during test 0.5339488387107849

# %%
original=[]
predictions=[]
images=[]

for i in range(len(os.listdir(test_dir))):
    for items in os.listdir(os.path.join(test_dir,label_names[i])):
        image=cv2.imread(os.path.join(test_dir,label_names[i],items))
        image=cv2.resize(image,(48,48))
        images.append(image)
        image=image/255
        image=image.reshape((-1,48,48,1))
        predict=model.predict(image)
        predict=np.argmax(predict)
        predictions.append(predict)
        original.append(i)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
score=accuracy_score(original,predictions)
print('Test Accuracy {}'.format(score))
# Out:
# Test Accuracy 0.07146900651004812

# %%
print(classification_report(np.asarray(original),np.asarray(predictions)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       960
#            1       0.00      0.00      0.00       111
#            2       0.00      0.00      0.00      1018
#            3       0.25      0.26      0.25      1825
#            4       0.18      0.03      0.05      1216
#            5       0.00      0.00      0.00      1139
#            6       0.00      0.00      0.00       797
#            7       0.00      0.00      0.00         0
#           10       0.00      0.00      0.00         0
#           11       0.00      0.00      0.00         0
#           17       0.00      0.00      0.00         0
#           18       0.00      0.00      0.00         0
#
#     accuracy                           0.07      7066
#    macro avg       0.04      0.02      0.03      7066
# weighted avg       0.10      0.07      0.07      7066

# %%
cm=confusion_matrix(np.asarray(original),np.asarray(predictions))
ax=plt.subplot()

sn.heatmap(cm,annot=True,ax=ax)
ax.set_xlabel('Predicted')
ax.set_ylabel('Original')
# Out:
# Text(33.0, 0.5, 'Original')

# %%
#Transfer Learning

train_set=ImageDataGenerator(rotation_range=15,
                            rescale=1./255,
                              shear_range=0.2,
                            zoom_range=0.1,
                            width_shift_range=0.1,
                            height_shift_range=0.1)
train_gen=train_set.flow_from_directory(train_dir,target_size=(256,256),shuffle=True,class_mode='categorical',batch_size=64)
# Out:
# Found 28820 images belonging to 7 classes.

# %%
train_images,train_labels=next(train_gen)

# %%
train_images.shape
# Out:
# (64, 256, 256, 3)

# %%
train_labels.shape
# Out:
# (64, 7)

# %%
label_names={0:'angry',1:'disgust',2:'fear',3:'happy',4:'neutral',5:'sad',6:'surprise'}

# %%
l=8
w=8
fig,axes=plt.subplots(l,w,figsize=(16,12))
axes=axes.ravel()

for i in np.arange(0,l*w):
    axes[i].imshow(train_images[i])
    axes[i].set_title(label_names[np.argmax(train_labels[i])])
    axes[i].axis('off')
    
    plt.subplots_adjust(wspace=0.5)

# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3

# %%
basemodel=InceptionV3(weights='imagenet',include_top=False,input_tensor=Input(shape=(256,256,3)))

# %%
basemodel.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_4 (Conv2D)              (None, 127, 127, 32  864         ['input_1[0][0]']
#                                 )
#
#  batch_normalization_6 (BatchNo  (None, 127, 127, 32  96         ['conv2d_4[0][0]']
#  rmalization)                   )
#
#  activation (Activation)        (None, 127, 127, 32  0           ['batch_normalization_6[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 125, 125, 32  9216        ['activation[0][0]']
#                                 )
#
#  batch_normalization_7 (BatchNo  (None, 125, 125, 32  96         ['conv2d_5[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 125, 125, 32  0           ['batch_normalization_7[0][0]']
#                                 )
#
#  conv2d_6 (Conv2D)              (None, 125, 125, 64  18432       ['activation_1[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 125, 125, 64  192        ['conv2d_6[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 125, 125, 64  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 62, 62, 64)  0           ['activation_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 62, 62, 80)   5120        ['max_pooling2d_4[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 62, 62, 80)  240         ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 62, 62, 80)   0           ['batch_normalization_9[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 60, 60, 192)  138240      ['activation_3[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 60, 60, 192)  576        ['conv2d_8[0][0]']
#  ormalization)
#
#  activation_4 (Activation)      (None, 60, 60, 192)  0           ['batch_normalization_10[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 29, 29, 192)  0          ['activation_4[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 29, 29, 64)   12288       ['max_pooling2d_5[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 29, 29, 64)  192         ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_8 (Activation)      (None, 29, 29, 64)   0           ['batch_normalization_14[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 29, 29, 48)   9216        ['max_pooling2d_5[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 29, 29, 96)   55296       ['activation_8[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 29, 29, 48)  144         ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_15 (BatchN  (None, 29, 29, 96)  288         ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_6 (Activation)      (None, 29, 29, 48)   0           ['batch_normalization_12[0][0]']
#
#  activation_9 (Activation)      (None, 29, 29, 96)   0           ['batch_normalization_15[0][0]']
#
#  average_pooling2d (AveragePool  (None, 29, 29, 192)  0          ['max_pooling2d_5[0][0]']
#  ing2D)
#
#  conv2d_9 (Conv2D)              (None, 29, 29, 64)   12288       ['max_pooling2d_5[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 29, 29, 64)   76800       ['activation_6[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 29, 29, 96)   82944       ['activation_9[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 29, 29, 32)   6144        ['average_pooling2d[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 29, 29, 64)  192         ['conv2d_9[0][0]']
#  ormalization)
#
#  batch_normalization_13 (BatchN  (None, 29, 29, 64)  192         ['conv2d_11[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 29, 29, 96)  288         ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 29, 29, 32)  96          ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 29, 29, 64)   0           ['batch_normalization_11[0][0]']
#
#  activation_7 (Activation)      (None, 29, 29, 64)   0           ['batch_normalization_13[0][0]']
#
#  activation_10 (Activation)     (None, 29, 29, 96)   0           ['batch_normalization_16[0][0]']
#
#  activation_11 (Activation)     (None, 29, 29, 32)   0           ['batch_normalization_17[0][0]']
#
#  mixed0 (Concatenate)           (None, 29, 29, 256)  0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 29, 29, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 29, 29, 64)  192         ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 29, 29, 64)   0           ['batch_normalization_21[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 29, 29, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 29, 29, 96)   55296       ['activation_15[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 29, 29, 48)  144         ['conv2d_17[0][0]']
#  ormalization)
#
#  batch_normalization_22 (BatchN  (None, 29, 29, 96)  288         ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 29, 29, 48)   0           ['batch_normalization_19[0][0]']
#
#  activation_16 (Activation)     (None, 29, 29, 96)   0           ['batch_normalization_22[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 29, 29, 256)  0          ['mixed0[0][0]']
#  oling2D)
#
#  conv2d_16 (Conv2D)             (None, 29, 29, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 29, 29, 64)   76800       ['activation_13[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 29, 29, 96)   82944       ['activation_16[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 29, 29, 64)   16384       ['average_pooling2d_1[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 29, 29, 64)  192         ['conv2d_16[0][0]']
#  ormalization)
#
#  batch_normalization_20 (BatchN  (None, 29, 29, 64)  192         ['conv2d_18[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 29, 29, 96)  288         ['conv2d_21[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 29, 29, 64)  192         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 29, 29, 64)   0           ['batch_normalization_18[0][0]']
#
#  activation_14 (Activation)     (None, 29, 29, 64)   0           ['batch_normalization_20[0][0]']
#
#  activation_17 (Activation)     (None, 29, 29, 96)   0           ['batch_normalization_23[0][0]']
#
#  activation_18 (Activation)     (None, 29, 29, 64)   0           ['batch_normalization_24[0][0]']
#
#  mixed1 (Concatenate)           (None, 29, 29, 288)  0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]',
#                                                                   'activation_18[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 29, 29, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 29, 29, 64)  192         ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 29, 29, 64)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 29, 29, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 29, 29, 96)   55296       ['activation_22[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 29, 29, 48)  144         ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 29, 29, 96)  288         ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 29, 29, 48)   0           ['batch_normalization_26[0][0]']
#
#  activation_23 (Activation)     (None, 29, 29, 96)   0           ['batch_normalization_29[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 29, 29, 288)  0          ['mixed1[0][0]']
#  oling2D)
#
#  conv2d_23 (Conv2D)             (None, 29, 29, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 29, 29, 64)   76800       ['activation_20[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 29, 29, 96)   82944       ['activation_23[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 29, 29, 64)   18432       ['average_pooling2d_2[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 29, 29, 64)  192         ['conv2d_23[0][0]']
#  ormalization)
#
#  batch_normalization_27 (BatchN  (None, 29, 29, 64)  192         ['conv2d_25[0][0]']
#  ormalization)
#
#  batch_normalization_30 (BatchN  (None, 29, 29, 96)  288         ['conv2d_28[0][0]']
#  ormalization)
#
#  batch_normalization_31 (BatchN  (None, 29, 29, 64)  192         ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 29, 29, 64)   0           ['batch_normalization_25[0][0]']
#
#  activation_21 (Activation)     (None, 29, 29, 64)   0           ['batch_normalization_27[0][0]']
#
#  activation_24 (Activation)     (None, 29, 29, 96)   0           ['batch_normalization_30[0][0]']
#
#  activation_25 (Activation)     (None, 29, 29, 64)   0           ['batch_normalization_31[0][0]']
#
#  mixed2 (Concatenate)           (None, 29, 29, 288)  0           ['activation_19[0][0]',
#                                                                   'activation_21[0][0]',
#                                                                   'activation_24[0][0]',
#                                                                   'activation_25[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 29, 29, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 29, 29, 64)  192         ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 29, 29, 64)   0           ['batch_normalization_33[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 29, 29, 96)   55296       ['activation_27[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 29, 29, 96)  288         ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 29, 29, 96)   0           ['batch_normalization_34[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 14, 14, 384)  995328      ['mixed2[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 14, 14, 96)   82944       ['activation_28[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 14, 14, 384)  1152       ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_35 (BatchN  (None, 14, 14, 96)  288         ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 14, 14, 384)  0           ['batch_normalization_32[0][0]']
#
#  activation_29 (Activation)     (None, 14, 14, 96)   0           ['batch_normalization_35[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 14, 14, 288)  0          ['mixed2[0][0]']
#
#  mixed3 (Concatenate)           (None, 14, 14, 768)  0           ['activation_26[0][0]',
#                                                                   'activation_29[0][0]',
#                                                                   'max_pooling2d_6[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 14, 14, 128)  98304       ['mixed3[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 14, 14, 128)  384        ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 14, 14, 128)  0           ['batch_normalization_40[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 14, 14, 128)  114688      ['activation_34[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 14, 14, 128)  384        ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 14, 14, 128)  0           ['batch_normalization_41[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 14, 14, 128)  98304       ['mixed3[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 14, 14, 128)  114688      ['activation_35[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 14, 14, 128)  384        ['conv2d_35[0][0]']
#  ormalization)
#
#  batch_normalization_42 (BatchN  (None, 14, 14, 128)  384        ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 14, 14, 128)  0           ['batch_normalization_37[0][0]']
#
#  activation_36 (Activation)     (None, 14, 14, 128)  0           ['batch_normalization_42[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 14, 14, 128)  114688      ['activation_31[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 14, 14, 128)  114688      ['activation_36[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 14, 14, 128)  384        ['conv2d_36[0][0]']
#  ormalization)
#
#  batch_normalization_43 (BatchN  (None, 14, 14, 128)  384        ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 14, 14, 128)  0           ['batch_normalization_38[0][0]']
#
#  activation_37 (Activation)     (None, 14, 14, 128)  0           ['batch_normalization_43[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 14, 14, 768)  0          ['mixed3[0][0]']
#  oling2D)
#
#  conv2d_34 (Conv2D)             (None, 14, 14, 192)  147456      ['mixed3[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 14, 14, 192)  172032      ['activation_32[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 14, 14, 192)  172032      ['activation_37[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 14, 14, 192)  147456      ['average_pooling2d_3[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 14, 14, 192)  576        ['conv2d_34[0][0]']
#  ormalization)
#
#  batch_normalization_39 (BatchN  (None, 14, 14, 192)  576        ['conv2d_37[0][0]']
#  ormalization)
#
#  batch_normalization_44 (BatchN  (None, 14, 14, 192)  576        ['conv2d_42[0][0]']
#  ormalization)
#
#  batch_normalization_45 (BatchN  (None, 14, 14, 192)  576        ['conv2d_43[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 14, 14, 192)  0           ['batch_normalization_36[0][0]']
#
#  activation_33 (Activation)     (None, 14, 14, 192)  0           ['batch_normalization_39[0][0]']
#
#  activation_38 (Activation)     (None, 14, 14, 192)  0           ['batch_normalization_44[0][0]']
#
#  activation_39 (Activation)     (None, 14, 14, 192)  0           ['batch_normalization_45[0][0]']
#
#  mixed4 (Concatenate)           (None, 14, 14, 768)  0           ['activation_30[0][0]',
#                                                                   'activation_33[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_39[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 14, 14, 160)  122880      ['mixed4[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 14, 14, 160)  480        ['conv2d_48[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 14, 14, 160)  0           ['batch_normalization_50[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 14, 14, 160)  179200      ['activation_44[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 14, 14, 160)  480        ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 14, 14, 160)  0           ['batch_normalization_51[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 14, 14, 160)  122880      ['mixed4[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 14, 14, 160)  179200      ['activation_45[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 14, 14, 160)  480        ['conv2d_45[0][0]']
#  ormalization)
#
#  batch_normalization_52 (BatchN  (None, 14, 14, 160)  480        ['conv2d_50[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 14, 14, 160)  0           ['batch_normalization_47[0][0]']
#
#  activation_46 (Activation)     (None, 14, 14, 160)  0           ['batch_normalization_52[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 14, 14, 160)  179200      ['activation_41[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 14, 14, 160)  179200      ['activation_46[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 14, 14, 160)  480        ['conv2d_46[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 14, 14, 160)  480        ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 14, 14, 160)  0           ['batch_normalization_48[0][0]']
#
#  activation_47 (Activation)     (None, 14, 14, 160)  0           ['batch_normalization_53[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 14, 14, 768)  0          ['mixed4[0][0]']
#  oling2D)
#
#  conv2d_44 (Conv2D)             (None, 14, 14, 192)  147456      ['mixed4[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 14, 14, 192)  215040      ['activation_42[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 14, 14, 192)  215040      ['activation_47[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 14, 14, 192)  147456      ['average_pooling2d_4[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 14, 14, 192)  576        ['conv2d_44[0][0]']
#  ormalization)
#
#  batch_normalization_49 (BatchN  (None, 14, 14, 192)  576        ['conv2d_47[0][0]']
#  ormalization)
#
#  batch_normalization_54 (BatchN  (None, 14, 14, 192)  576        ['conv2d_52[0][0]']
#  ormalization)
#
#  batch_normalization_55 (BatchN  (None, 14, 14, 192)  576        ['conv2d_53[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 14, 14, 192)  0           ['batch_normalization_46[0][0]']
#
#  activation_43 (Activation)     (None, 14, 14, 192)  0           ['batch_normalization_49[0][0]']
#
#  activation_48 (Activation)     (None, 14, 14, 192)  0           ['batch_normalization_54[0][0]']
#
#  activation_49 (Activation)     (None, 14, 14, 192)  0           ['batch_normalization_55[0][0]']
#
#  mixed5 (Concatenate)           (None, 14, 14, 768)  0           ['activation_40[0][0]',
#                                                                   'activation_43[0][0]',
#                                                                   'activation_48[0][0]',
#                                                                   'activation_49[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 14, 14, 160)  122880      ['mixed5[0][0]']
#
#  batch_normalization_60 (BatchN  (None, 14, 14, 160)  480        ['conv2d_58[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 14, 14, 160)  0           ['batch_normalization_60[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 14, 14, 160)  179200      ['activation_54[0][0]']
#
#  batch_normalization_61 (BatchN  (None, 14, 14, 160)  480        ['conv2d_59[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 14, 14, 160)  0           ['batch_normalization_61[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 14, 14, 160)  122880      ['mixed5[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 14, 14, 160)  179200      ['activation_55[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 14, 14, 160)  480        ['conv2d_55[0][0]']
#  ormalization)
#
#  batch_normalization_62 (BatchN  (None, 14, 14, 160)  480        ['conv2d_60[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 14, 14, 160)  0           ['batch_normalization_57[0][0]']
#
#  activation_56 (Activation)     (None, 14, 14, 160)  0           ['batch_normalization_62[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 14, 14, 160)  179200      ['activation_51[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 14, 14, 160)  179200      ['activation_56[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 14, 14, 160)  480        ['conv2d_56[0][0]']
#  ormalization)
#
#  batch_normalization_63 (BatchN  (None, 14, 14, 160)  480        ['conv2d_61[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 14, 14, 160)  0           ['batch_normalization_58[0][0]']
#
#  activation_57 (Activation)     (None, 14, 14, 160)  0           ['batch_normalization_63[0][0]']
#
#  average_pooling2d_5 (AveragePo  (None, 14, 14, 768)  0          ['mixed5[0][0]']
#  oling2D)
#
#  conv2d_54 (Conv2D)             (None, 14, 14, 192)  147456      ['mixed5[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 14, 14, 192)  215040      ['activation_52[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 14, 14, 192)  215040      ['activation_57[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 14, 14, 192)  147456      ['average_pooling2d_5[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 14, 14, 192)  576        ['conv2d_54[0][0]']
#  ormalization)
#
#  batch_normalization_59 (BatchN  (None, 14, 14, 192)  576        ['conv2d_57[0][0]']
#  ormalization)
#
#  batch_normalization_64 (BatchN  (None, 14, 14, 192)  576        ['conv2d_62[0][0]']
#  ormalization)
#
#  batch_normalization_65 (BatchN  (None, 14, 14, 192)  576        ['conv2d_63[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 14, 14, 192)  0           ['batch_normalization_56[0][0]']
#
#  activation_53 (Activation)     (None, 14, 14, 192)  0           ['batch_normalization_59[0][0]']
#
#  activation_58 (Activation)     (None, 14, 14, 192)  0           ['batch_normalization_64[0][0]']
#
#  activation_59 (Activation)     (None, 14, 14, 192)  0           ['batch_normalization_65[0][0]']
# ...
#  mixed8 (Concatenate)           (None, 6, 6, 1280)   0           ['activation_71[0][0]',
#                                                                   'activation_75[0][0]',
#                                                                   'max_pooling2d_7[0][0]']
#
#  conv2d_84 (Conv2D)             (None, 6, 6, 448)    573440      ['mixed8[0][0]']
#
#  batch_normalization_86 (BatchN  (None, 6, 6, 448)   1344        ['conv2d_84[0][0]']
#  ormalization)
#
#  activation_80 (Activation)     (None, 6, 6, 448)    0           ['batch_normalization_86[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 6, 6, 384)    491520      ['mixed8[0][0]']
#
#  conv2d_85 (Conv2D)             (None, 6, 6, 384)    1548288     ['activation_80[0][0]']
#
#  batch_normalization_83 (BatchN  (None, 6, 6, 384)   1152        ['conv2d_81[0][0]']
#  ormalization)
#
#  batch_normalization_87 (BatchN  (None, 6, 6, 384)   1152        ['conv2d_85[0][0]']
#  ormalization)
#
#  activation_77 (Activation)     (None, 6, 6, 384)    0           ['batch_normalization_83[0][0]']
#
#  activation_81 (Activation)     (None, 6, 6, 384)    0           ['batch_normalization_87[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 6, 6, 384)    442368      ['activation_77[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 6, 6, 384)    442368      ['activation_77[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 6, 6, 384)    442368      ['activation_81[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 6, 6, 384)    442368      ['activation_81[0][0]']
#
#  average_pooling2d_7 (AveragePo  (None, 6, 6, 1280)  0           ['mixed8[0][0]']
#  oling2D)
#
#  conv2d_80 (Conv2D)             (None, 6, 6, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_84 (BatchN  (None, 6, 6, 384)   1152        ['conv2d_82[0][0]']
#  ormalization)
#
#  batch_normalization_85 (BatchN  (None, 6, 6, 384)   1152        ['conv2d_83[0][0]']
#  ormalization)
#
#  batch_normalization_88 (BatchN  (None, 6, 6, 384)   1152        ['conv2d_86[0][0]']
#  ormalization)
#
#  batch_normalization_89 (BatchN  (None, 6, 6, 384)   1152        ['conv2d_87[0][0]']
#  ormalization)
#
#  conv2d_88 (Conv2D)             (None, 6, 6, 192)    245760      ['average_pooling2d_7[0][0]']
#
#  batch_normalization_82 (BatchN  (None, 6, 6, 320)   960         ['conv2d_80[0][0]']
#  ormalization)
#
#  activation_78 (Activation)     (None, 6, 6, 384)    0           ['batch_normalization_84[0][0]']
#
#  activation_79 (Activation)     (None, 6, 6, 384)    0           ['batch_normalization_85[0][0]']
#
#  activation_82 (Activation)     (None, 6, 6, 384)    0           ['batch_normalization_88[0][0]']
#
#  activation_83 (Activation)     (None, 6, 6, 384)    0           ['batch_normalization_89[0][0]']
#
#  batch_normalization_90 (BatchN  (None, 6, 6, 192)   576         ['conv2d_88[0][0]']
#  ormalization)
#
#  activation_76 (Activation)     (None, 6, 6, 320)    0           ['batch_normalization_82[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 6, 6, 768)    0           ['activation_78[0][0]',
#                                                                   'activation_79[0][0]']
#
#  concatenate (Concatenate)      (None, 6, 6, 768)    0           ['activation_82[0][0]',
#                                                                   'activation_83[0][0]']
#
#  activation_84 (Activation)     (None, 6, 6, 192)    0           ['batch_normalization_90[0][0]']
#
#  mixed9 (Concatenate)           (None, 6, 6, 2048)   0           ['activation_76[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate[0][0]',
#                                                                   'activation_84[0][0]']
#
#  conv2d_93 (Conv2D)             (None, 6, 6, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_95 (BatchN  (None, 6, 6, 448)   1344        ['conv2d_93[0][0]']
#  ormalization)
#
#  activation_89 (Activation)     (None, 6, 6, 448)    0           ['batch_normalization_95[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 6, 6, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_94 (Conv2D)             (None, 6, 6, 384)    1548288     ['activation_89[0][0]']
#
#  batch_normalization_92 (BatchN  (None, 6, 6, 384)   1152        ['conv2d_90[0][0]']
#  ormalization)
#
#  batch_normalization_96 (BatchN  (None, 6, 6, 384)   1152        ['conv2d_94[0][0]']
#  ormalization)
#
#  activation_86 (Activation)     (None, 6, 6, 384)    0           ['batch_normalization_92[0][0]']
#
#  activation_90 (Activation)     (None, 6, 6, 384)    0           ['batch_normalization_96[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 6, 6, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 6, 6, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_95 (Conv2D)             (None, 6, 6, 384)    442368      ['activation_90[0][0]']
#
#  conv2d_96 (Conv2D)             (None, 6, 6, 384)    442368      ['activation_90[0][0]']
#
#  average_pooling2d_8 (AveragePo  (None, 6, 6, 2048)  0           ['mixed9[0][0]']
#  oling2D)
#
#  conv2d_89 (Conv2D)             (None, 6, 6, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 6, 6, 384)   1152        ['conv2d_91[0][0]']
#  ormalization)
#
#  batch_normalization_94 (BatchN  (None, 6, 6, 384)   1152        ['conv2d_92[0][0]']
#  ormalization)
#
#  batch_normalization_97 (BatchN  (None, 6, 6, 384)   1152        ['conv2d_95[0][0]']
#  ormalization)
#
#  batch_normalization_98 (BatchN  (None, 6, 6, 384)   1152        ['conv2d_96[0][0]']
#  ormalization)
#
#  conv2d_97 (Conv2D)             (None, 6, 6, 192)    393216      ['average_pooling2d_8[0][0]']
#
#  batch_normalization_91 (BatchN  (None, 6, 6, 320)   960         ['conv2d_89[0][0]']
#  ormalization)
#
#  activation_87 (Activation)     (None, 6, 6, 384)    0           ['batch_normalization_93[0][0]']
#
#  activation_88 (Activation)     (None, 6, 6, 384)    0           ['batch_normalization_94[0][0]']
#
#  activation_91 (Activation)     (None, 6, 6, 384)    0           ['batch_normalization_97[0][0]']
#
#  activation_92 (Activation)     (None, 6, 6, 384)    0           ['batch_normalization_98[0][0]']
#
#  batch_normalization_99 (BatchN  (None, 6, 6, 192)   576         ['conv2d_97[0][0]']
#  ormalization)
#
#  activation_85 (Activation)     (None, 6, 6, 320)    0           ['batch_normalization_91[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 6, 6, 768)    0           ['activation_87[0][0]',
#                                                                   'activation_88[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 6, 6, 768)    0           ['activation_91[0][0]',
#                                                                   'activation_92[0][0]']
#
#  activation_93 (Activation)     (None, 6, 6, 192)    0           ['batch_normalization_99[0][0]']
#
#  mixed10 (Concatenate)          (None, 6, 6, 2048)   0           ['activation_85[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_1[0][0]',
#                                                                   'activation_93[0][0]']
#
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 21,768,352
# Non-trainable params: 34,432
# __________________________________________________________________________________________________

# %%
for layers in basemodel.layers[:-10]:
    layers.trainable=False

# %%
from tensorflow.keras import backend as k

# %%
def precision(y_true,y_pred):
    true_positives=k.sum(k.round(k.clip(y_true*y_pred,0,1)))
    predicted_positives=k.sum(k.round(k.clip(y_pred,0,1)))
    precision=true_positives/(predicted_positives+k.epsilon())
    return precision
def recall(y_true,y_pred):
    true_positives=k.sum(k.round(k.clip(y_true*y_pred,0,1)))
    predicted_positives=k.sum(k.round(k.clip(y_pred,0,1)))
    recall=true_positives/(predicted_positives+k.epsilon())
    return recall
def f1(y_true,y_pred):
    def recall(y_true,y_pred):
        true_positives=k.sum(k.round(k.clip(y_true*y_pred,0,1)))
        predicted_positives=k.sum(k.round(k.clip(y_pred,0,1)))
        recall=true_positives/(predicted_positives+k.epsilon())
        return recall
    def precision(y_true,y_pred):
        true_positives=k.sum(k.round(k.clip(y_true*y_pred,0,1)))
        predicted_positives=k.sum(k.round(k.clip(y_pred,0,1)))
        precision=true_positives/(predicted_positives+k.epsilon())
        return precision
    precision=precision(y_true,y_pred)
    recall=recall(y_true,y_pred)
    return 2*((precision*recall)/(precision+recall+k.epsilon()))

# %%
headmodel=basemodel.output
headmodel=AveragePooling2D(pool_size=(4,4))(headmodel)
headmodel=Flatten(name='flatten')(headmodel)

headmodel=Dense(256,activation='relu')(headmodel)
headmodel=BatchNormalization()(headmodel)
headmodel=Dropout(0.5)(headmodel)

headmodel=Dense(128,activation='relu')(headmodel)
headmodel=BatchNormalization()(headmodel)
headmodel=Dropout(0.5)(headmodel)

headmodel=Dense(64,activation='relu')(headmodel)
headmodel=BatchNormalization()(headmodel)
headmodel=Dropout(0.5)(headmodel)

headmodel=Dense(7,activation='softmax')(headmodel)

model=Model(inputs=basemodel.input,outputs=headmodel)

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_4 (Conv2D)              (None, 127, 127, 32  864         ['input_1[0][0]']
#                                 )
#
#  batch_normalization_6 (BatchNo  (None, 127, 127, 32  96         ['conv2d_4[0][0]']
#  rmalization)                   )
#
#  activation (Activation)        (None, 127, 127, 32  0           ['batch_normalization_6[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 125, 125, 32  9216        ['activation[0][0]']
#                                 )
#
#  batch_normalization_7 (BatchNo  (None, 125, 125, 32  96         ['conv2d_5[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 125, 125, 32  0           ['batch_normalization_7[0][0]']
#                                 )
#
#  conv2d_6 (Conv2D)              (None, 125, 125, 64  18432       ['activation_1[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 125, 125, 64  192        ['conv2d_6[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 125, 125, 64  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 62, 62, 64)  0           ['activation_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 62, 62, 80)   5120        ['max_pooling2d_4[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 62, 62, 80)  240         ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 62, 62, 80)   0           ['batch_normalization_9[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 60, 60, 192)  138240      ['activation_3[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 60, 60, 192)  576        ['conv2d_8[0][0]']
#  ormalization)
#
#  activation_4 (Activation)      (None, 60, 60, 192)  0           ['batch_normalization_10[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 29, 29, 192)  0          ['activation_4[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 29, 29, 64)   12288       ['max_pooling2d_5[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 29, 29, 64)  192         ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_8 (Activation)      (None, 29, 29, 64)   0           ['batch_normalization_14[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 29, 29, 48)   9216        ['max_pooling2d_5[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 29, 29, 96)   55296       ['activation_8[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 29, 29, 48)  144         ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_15 (BatchN  (None, 29, 29, 96)  288         ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_6 (Activation)      (None, 29, 29, 48)   0           ['batch_normalization_12[0][0]']
#
#  activation_9 (Activation)      (None, 29, 29, 96)   0           ['batch_normalization_15[0][0]']
#
#  average_pooling2d (AveragePool  (None, 29, 29, 192)  0          ['max_pooling2d_5[0][0]']
#  ing2D)
#
#  conv2d_9 (Conv2D)              (None, 29, 29, 64)   12288       ['max_pooling2d_5[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 29, 29, 64)   76800       ['activation_6[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 29, 29, 96)   82944       ['activation_9[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 29, 29, 32)   6144        ['average_pooling2d[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 29, 29, 64)  192         ['conv2d_9[0][0]']
#  ormalization)
#
#  batch_normalization_13 (BatchN  (None, 29, 29, 64)  192         ['conv2d_11[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 29, 29, 96)  288         ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 29, 29, 32)  96          ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 29, 29, 64)   0           ['batch_normalization_11[0][0]']
#
#  activation_7 (Activation)      (None, 29, 29, 64)   0           ['batch_normalization_13[0][0]']
#
#  activation_10 (Activation)     (None, 29, 29, 96)   0           ['batch_normalization_16[0][0]']
#
#  activation_11 (Activation)     (None, 29, 29, 32)   0           ['batch_normalization_17[0][0]']
#
#  mixed0 (Concatenate)           (None, 29, 29, 256)  0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 29, 29, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 29, 29, 64)  192         ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 29, 29, 64)   0           ['batch_normalization_21[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 29, 29, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 29, 29, 96)   55296       ['activation_15[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 29, 29, 48)  144         ['conv2d_17[0][0]']
#  ormalization)
#
#  batch_normalization_22 (BatchN  (None, 29, 29, 96)  288         ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 29, 29, 48)   0           ['batch_normalization_19[0][0]']
#
#  activation_16 (Activation)     (None, 29, 29, 96)   0           ['batch_normalization_22[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 29, 29, 256)  0          ['mixed0[0][0]']
#  oling2D)
#
#  conv2d_16 (Conv2D)             (None, 29, 29, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 29, 29, 64)   76800       ['activation_13[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 29, 29, 96)   82944       ['activation_16[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 29, 29, 64)   16384       ['average_pooling2d_1[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 29, 29, 64)  192         ['conv2d_16[0][0]']
#  ormalization)
#
#  batch_normalization_20 (BatchN  (None, 29, 29, 64)  192         ['conv2d_18[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 29, 29, 96)  288         ['conv2d_21[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 29, 29, 64)  192         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 29, 29, 64)   0           ['batch_normalization_18[0][0]']
#
#  activation_14 (Activation)     (None, 29, 29, 64)   0           ['batch_normalization_20[0][0]']
#
#  activation_17 (Activation)     (None, 29, 29, 96)   0           ['batch_normalization_23[0][0]']
#
#  activation_18 (Activation)     (None, 29, 29, 64)   0           ['batch_normalization_24[0][0]']
#
#  mixed1 (Concatenate)           (None, 29, 29, 288)  0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]',
#                                                                   'activation_18[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 29, 29, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 29, 29, 64)  192         ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 29, 29, 64)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 29, 29, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 29, 29, 96)   55296       ['activation_22[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 29, 29, 48)  144         ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 29, 29, 96)  288         ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 29, 29, 48)   0           ['batch_normalization_26[0][0]']
#
#  activation_23 (Activation)     (None, 29, 29, 96)   0           ['batch_normalization_29[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 29, 29, 288)  0          ['mixed1[0][0]']
#  oling2D)
#
#  conv2d_23 (Conv2D)             (None, 29, 29, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 29, 29, 64)   76800       ['activation_20[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 29, 29, 96)   82944       ['activation_23[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 29, 29, 64)   18432       ['average_pooling2d_2[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 29, 29, 64)  192         ['conv2d_23[0][0]']
#  ormalization)
#
#  batch_normalization_27 (BatchN  (None, 29, 29, 64)  192         ['conv2d_25[0][0]']
#  ormalization)
#
#  batch_normalization_30 (BatchN  (None, 29, 29, 96)  288         ['conv2d_28[0][0]']
#  ormalization)
#
#  batch_normalization_31 (BatchN  (None, 29, 29, 64)  192         ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 29, 29, 64)   0           ['batch_normalization_25[0][0]']
#
#  activation_21 (Activation)     (None, 29, 29, 64)   0           ['batch_normalization_27[0][0]']
#
#  activation_24 (Activation)     (None, 29, 29, 96)   0           ['batch_normalization_30[0][0]']
#
#  activation_25 (Activation)     (None, 29, 29, 64)   0           ['batch_normalization_31[0][0]']
#
#  mixed2 (Concatenate)           (None, 29, 29, 288)  0           ['activation_19[0][0]',
#                                                                   'activation_21[0][0]',
#                                                                   'activation_24[0][0]',
#                                                                   'activation_25[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 29, 29, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 29, 29, 64)  192         ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 29, 29, 64)   0           ['batch_normalization_33[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 29, 29, 96)   55296       ['activation_27[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 29, 29, 96)  288         ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 29, 29, 96)   0           ['batch_normalization_34[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 14, 14, 384)  995328      ['mixed2[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 14, 14, 96)   82944       ['activation_28[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 14, 14, 384)  1152       ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_35 (BatchN  (None, 14, 14, 96)  288         ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 14, 14, 384)  0           ['batch_normalization_32[0][0]']
#
#  activation_29 (Activation)     (None, 14, 14, 96)   0           ['batch_normalization_35[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 14, 14, 288)  0          ['mixed2[0][0]']
#
#  mixed3 (Concatenate)           (None, 14, 14, 768)  0           ['activation_26[0][0]',
#                                                                   'activation_29[0][0]',
#                                                                   'max_pooling2d_6[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 14, 14, 128)  98304       ['mixed3[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 14, 14, 128)  384        ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 14, 14, 128)  0           ['batch_normalization_40[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 14, 14, 128)  114688      ['activation_34[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 14, 14, 128)  384        ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 14, 14, 128)  0           ['batch_normalization_41[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 14, 14, 128)  98304       ['mixed3[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 14, 14, 128)  114688      ['activation_35[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 14, 14, 128)  384        ['conv2d_35[0][0]']
#  ormalization)
#
#  batch_normalization_42 (BatchN  (None, 14, 14, 128)  384        ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 14, 14, 128)  0           ['batch_normalization_37[0][0]']
#
#  activation_36 (Activation)     (None, 14, 14, 128)  0           ['batch_normalization_42[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 14, 14, 128)  114688      ['activation_31[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 14, 14, 128)  114688      ['activation_36[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 14, 14, 128)  384        ['conv2d_36[0][0]']
#  ormalization)
#
#  batch_normalization_43 (BatchN  (None, 14, 14, 128)  384        ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 14, 14, 128)  0           ['batch_normalization_38[0][0]']
#
#  activation_37 (Activation)     (None, 14, 14, 128)  0           ['batch_normalization_43[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 14, 14, 768)  0          ['mixed3[0][0]']
#  oling2D)
#
#  conv2d_34 (Conv2D)             (None, 14, 14, 192)  147456      ['mixed3[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 14, 14, 192)  172032      ['activation_32[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 14, 14, 192)  172032      ['activation_37[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 14, 14, 192)  147456      ['average_pooling2d_3[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 14, 14, 192)  576        ['conv2d_34[0][0]']
#  ormalization)
#
#  batch_normalization_39 (BatchN  (None, 14, 14, 192)  576        ['conv2d_37[0][0]']
#  ormalization)
#
#  batch_normalization_44 (BatchN  (None, 14, 14, 192)  576        ['conv2d_42[0][0]']
#  ormalization)
#
#  batch_normalization_45 (BatchN  (None, 14, 14, 192)  576        ['conv2d_43[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 14, 14, 192)  0           ['batch_normalization_36[0][0]']
#
#  activation_33 (Activation)     (None, 14, 14, 192)  0           ['batch_normalization_39[0][0]']
#
#  activation_38 (Activation)     (None, 14, 14, 192)  0           ['batch_normalization_44[0][0]']
#
#  activation_39 (Activation)     (None, 14, 14, 192)  0           ['batch_normalization_45[0][0]']
#
#  mixed4 (Concatenate)           (None, 14, 14, 768)  0           ['activation_30[0][0]',
#                                                                   'activation_33[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_39[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 14, 14, 160)  122880      ['mixed4[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 14, 14, 160)  480        ['conv2d_48[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 14, 14, 160)  0           ['batch_normalization_50[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 14, 14, 160)  179200      ['activation_44[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 14, 14, 160)  480        ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 14, 14, 160)  0           ['batch_normalization_51[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 14, 14, 160)  122880      ['mixed4[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 14, 14, 160)  179200      ['activation_45[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 14, 14, 160)  480        ['conv2d_45[0][0]']
#  ormalization)
#
#  batch_normalization_52 (BatchN  (None, 14, 14, 160)  480        ['conv2d_50[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 14, 14, 160)  0           ['batch_normalization_47[0][0]']
#
#  activation_46 (Activation)     (None, 14, 14, 160)  0           ['batch_normalization_52[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 14, 14, 160)  179200      ['activation_41[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 14, 14, 160)  179200      ['activation_46[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 14, 14, 160)  480        ['conv2d_46[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 14, 14, 160)  480        ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 14, 14, 160)  0           ['batch_normalization_48[0][0]']
#
#  activation_47 (Activation)     (None, 14, 14, 160)  0           ['batch_normalization_53[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 14, 14, 768)  0          ['mixed4[0][0]']
#  oling2D)
#
#  conv2d_44 (Conv2D)             (None, 14, 14, 192)  147456      ['mixed4[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 14, 14, 192)  215040      ['activation_42[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 14, 14, 192)  215040      ['activation_47[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 14, 14, 192)  147456      ['average_pooling2d_4[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 14, 14, 192)  576        ['conv2d_44[0][0]']
#  ormalization)
#
#  batch_normalization_49 (BatchN  (None, 14, 14, 192)  576        ['conv2d_47[0][0]']
#  ormalization)
#
#  batch_normalization_54 (BatchN  (None, 14, 14, 192)  576        ['conv2d_52[0][0]']
#  ormalization)
#
#  batch_normalization_55 (BatchN  (None, 14, 14, 192)  576        ['conv2d_53[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 14, 14, 192)  0           ['batch_normalization_46[0][0]']
#
#  activation_43 (Activation)     (None, 14, 14, 192)  0           ['batch_normalization_49[0][0]']
#
#  activation_48 (Activation)     (None, 14, 14, 192)  0           ['batch_normalization_54[0][0]']
#
#  activation_49 (Activation)     (None, 14, 14, 192)  0           ['batch_normalization_55[0][0]']
#
#  mixed5 (Concatenate)           (None, 14, 14, 768)  0           ['activation_40[0][0]',
#                                                                   'activation_43[0][0]',
#                                                                   'activation_48[0][0]',
#                                                                   'activation_49[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 14, 14, 160)  122880      ['mixed5[0][0]']
#
#  batch_normalization_60 (BatchN  (None, 14, 14, 160)  480        ['conv2d_58[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 14, 14, 160)  0           ['batch_normalization_60[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 14, 14, 160)  179200      ['activation_54[0][0]']
#
#  batch_normalization_61 (BatchN  (None, 14, 14, 160)  480        ['conv2d_59[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 14, 14, 160)  0           ['batch_normalization_61[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 14, 14, 160)  122880      ['mixed5[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 14, 14, 160)  179200      ['activation_55[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 14, 14, 160)  480        ['conv2d_55[0][0]']
#  ormalization)
#
#  batch_normalization_62 (BatchN  (None, 14, 14, 160)  480        ['conv2d_60[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 14, 14, 160)  0           ['batch_normalization_57[0][0]']
#
#  activation_56 (Activation)     (None, 14, 14, 160)  0           ['batch_normalization_62[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 14, 14, 160)  179200      ['activation_51[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 14, 14, 160)  179200      ['activation_56[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 14, 14, 160)  480        ['conv2d_56[0][0]']
#  ormalization)
#
#  batch_normalization_63 (BatchN  (None, 14, 14, 160)  480        ['conv2d_61[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 14, 14, 160)  0           ['batch_normalization_58[0][0]']
#
#  activation_57 (Activation)     (None, 14, 14, 160)  0           ['batch_normalization_63[0][0]']
#
#  average_pooling2d_5 (AveragePo  (None, 14, 14, 768)  0          ['mixed5[0][0]']
#  oling2D)
#
#  conv2d_54 (Conv2D)             (None, 14, 14, 192)  147456      ['mixed5[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 14, 14, 192)  215040      ['activation_52[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 14, 14, 192)  215040      ['activation_57[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 14, 14, 192)  147456      ['average_pooling2d_5[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 14, 14, 192)  576        ['conv2d_54[0][0]']
#  ormalization)
#
#  batch_normalization_59 (BatchN  (None, 14, 14, 192)  576        ['conv2d_57[0][0]']
#  ormalization)
#
#  batch_normalization_64 (BatchN  (None, 14, 14, 192)  576        ['conv2d_62[0][0]']
#  ormalization)
#
#  batch_normalization_65 (BatchN  (None, 14, 14, 192)  576        ['conv2d_63[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 14, 14, 192)  0           ['batch_normalization_56[0][0]']
#
#  activation_53 (Activation)     (None, 14, 14, 192)  0           ['batch_normalization_59[0][0]']
#
#  activation_58 (Activation)     (None, 14, 14, 192)  0           ['batch_normalization_64[0][0]']
#
#  activation_59 (Activation)     (None, 14, 14, 192)  0           ['batch_normalization_65[0][0]']
# ...
#
#  conv2d_86 (Conv2D)             (None, 6, 6, 384)    442368      ['activation_81[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 6, 6, 384)    442368      ['activation_81[0][0]']
#
#  average_pooling2d_7 (AveragePo  (None, 6, 6, 1280)  0           ['mixed8[0][0]']
#  oling2D)
#
#  conv2d_80 (Conv2D)             (None, 6, 6, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_84 (BatchN  (None, 6, 6, 384)   1152        ['conv2d_82[0][0]']
#  ormalization)
#
#  batch_normalization_85 (BatchN  (None, 6, 6, 384)   1152        ['conv2d_83[0][0]']
#  ormalization)
#
#  batch_normalization_88 (BatchN  (None, 6, 6, 384)   1152        ['conv2d_86[0][0]']
#  ormalization)
#
#  batch_normalization_89 (BatchN  (None, 6, 6, 384)   1152        ['conv2d_87[0][0]']
#  ormalization)
#
#  conv2d_88 (Conv2D)             (None, 6, 6, 192)    245760      ['average_pooling2d_7[0][0]']
#
#  batch_normalization_82 (BatchN  (None, 6, 6, 320)   960         ['conv2d_80[0][0]']
#  ormalization)
#
#  activation_78 (Activation)     (None, 6, 6, 384)    0           ['batch_normalization_84[0][0]']
#
#  activation_79 (Activation)     (None, 6, 6, 384)    0           ['batch_normalization_85[0][0]']
#
#  activation_82 (Activation)     (None, 6, 6, 384)    0           ['batch_normalization_88[0][0]']
#
#  activation_83 (Activation)     (None, 6, 6, 384)    0           ['batch_normalization_89[0][0]']
#
#  batch_normalization_90 (BatchN  (None, 6, 6, 192)   576         ['conv2d_88[0][0]']
#  ormalization)
#
#  activation_76 (Activation)     (None, 6, 6, 320)    0           ['batch_normalization_82[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 6, 6, 768)    0           ['activation_78[0][0]',
#                                                                   'activation_79[0][0]']
#
#  concatenate (Concatenate)      (None, 6, 6, 768)    0           ['activation_82[0][0]',
#                                                                   'activation_83[0][0]']
#
#  activation_84 (Activation)     (None, 6, 6, 192)    0           ['batch_normalization_90[0][0]']
#
#  mixed9 (Concatenate)           (None, 6, 6, 2048)   0           ['activation_76[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate[0][0]',
#                                                                   'activation_84[0][0]']
#
#  conv2d_93 (Conv2D)             (None, 6, 6, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_95 (BatchN  (None, 6, 6, 448)   1344        ['conv2d_93[0][0]']
#  ormalization)
#
#  activation_89 (Activation)     (None, 6, 6, 448)    0           ['batch_normalization_95[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 6, 6, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_94 (Conv2D)             (None, 6, 6, 384)    1548288     ['activation_89[0][0]']
#
#  batch_normalization_92 (BatchN  (None, 6, 6, 384)   1152        ['conv2d_90[0][0]']
#  ormalization)
#
#  batch_normalization_96 (BatchN  (None, 6, 6, 384)   1152        ['conv2d_94[0][0]']
#  ormalization)
#
#  activation_86 (Activation)     (None, 6, 6, 384)    0           ['batch_normalization_92[0][0]']
#
#  activation_90 (Activation)     (None, 6, 6, 384)    0           ['batch_normalization_96[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 6, 6, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 6, 6, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_95 (Conv2D)             (None, 6, 6, 384)    442368      ['activation_90[0][0]']
#
#  conv2d_96 (Conv2D)             (None, 6, 6, 384)    442368      ['activation_90[0][0]']
#
#  average_pooling2d_8 (AveragePo  (None, 6, 6, 2048)  0           ['mixed9[0][0]']
#  oling2D)
#
#  conv2d_89 (Conv2D)             (None, 6, 6, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 6, 6, 384)   1152        ['conv2d_91[0][0]']
#  ormalization)
#
#  batch_normalization_94 (BatchN  (None, 6, 6, 384)   1152        ['conv2d_92[0][0]']
#  ormalization)
#
#  batch_normalization_97 (BatchN  (None, 6, 6, 384)   1152        ['conv2d_95[0][0]']
#  ormalization)
#
#  batch_normalization_98 (BatchN  (None, 6, 6, 384)   1152        ['conv2d_96[0][0]']
#  ormalization)
#
#  conv2d_97 (Conv2D)             (None, 6, 6, 192)    393216      ['average_pooling2d_8[0][0]']
#
#  batch_normalization_91 (BatchN  (None, 6, 6, 320)   960         ['conv2d_89[0][0]']
#  ormalization)
#
#  activation_87 (Activation)     (None, 6, 6, 384)    0           ['batch_normalization_93[0][0]']
#
#  activation_88 (Activation)     (None, 6, 6, 384)    0           ['batch_normalization_94[0][0]']
#
#  activation_91 (Activation)     (None, 6, 6, 384)    0           ['batch_normalization_97[0][0]']
#
#  activation_92 (Activation)     (None, 6, 6, 384)    0           ['batch_normalization_98[0][0]']
#
#  batch_normalization_99 (BatchN  (None, 6, 6, 192)   576         ['conv2d_97[0][0]']
#  ormalization)
#
#  activation_85 (Activation)     (None, 6, 6, 320)    0           ['batch_normalization_91[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 6, 6, 768)    0           ['activation_87[0][0]',
#                                                                   'activation_88[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 6, 6, 768)    0           ['activation_91[0][0]',
#                                                                   'activation_92[0][0]']
#
#  activation_93 (Activation)     (None, 6, 6, 192)    0           ['batch_normalization_99[0][0]']
#
#  mixed10 (Concatenate)          (None, 6, 6, 2048)   0           ['activation_85[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_1[0][0]',
#                                                                   'activation_93[0][0]']
#
#  average_pooling2d_9 (AveragePo  (None, 1, 1, 2048)  0           ['mixed10[0][0]']
#  oling2D)
#
#  flatten (Flatten)              (None, 2048)         0           ['average_pooling2d_9[0][0]']
#
#  dense_3 (Dense)                (None, 256)          524544      ['flatten[0][0]']
#
#  batch_normalization_100 (Batch  (None, 256)         1024        ['dense_3[0][0]']
#  Normalization)
#
#  dropout_6 (Dropout)            (None, 256)          0           ['batch_normalization_100[0][0]']
#
#  dense_4 (Dense)                (None, 128)          32896       ['dropout_6[0][0]']
#
#  batch_normalization_101 (Batch  (None, 128)         512         ['dense_4[0][0]']
#  Normalization)
#
#  dropout_7 (Dropout)            (None, 128)          0           ['batch_normalization_101[0][0]']
#
#  dense_5 (Dense)                (None, 64)           8256        ['dropout_7[0][0]']
#
#  batch_normalization_102 (Batch  (None, 64)          256         ['dense_5[0][0]']
#  Normalization)
#
#  dropout_8 (Dropout)            (None, 64)           0           ['batch_normalization_102[0][0]']
#
#  dense_6 (Dense)                (None, 7)            455         ['dropout_8[0][0]']
#
# ==================================================================================================
# Total params: 22,370,727
# Trainable params: 567,239
# Non-trainable params: 21,803,488
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop=EarlyStopping(monitor='val_loss',patience=2)
callback=[early_stop]

# %%
test_path=r"Data/data/test"
test_set=ImageDataGenerator(rotation_range=15,
                            rescale=1./255,
                              shear_range=0.2,
                            zoom_range=0.1,
                            width_shift_range=0.1,
                            height_shift_range=0.1)
valid_gen=test_set.flow_from_directory(test_path,target_size=(256,256),shuffle=True,class_mode='categorical',batch_size=64)
# Out:
# Found 7066 images belonging to 7 classes.

# %%
train_gen.n,valid_gen.n
# Out:
# (28820, 7066)

# %%
train_gen.batch_size
# Out:
# 64

# %%
history=model.fit_generator(train_gen,steps_per_epoch=(train_gen.n//train_gen.batch_size),epochs=10,validation_data=valid_gen,validation_steps=(valid_gen.n//valid_gen.batch_size),callbacks=callback)
# Out:
# Epoch 1/10
# 450/450 [==============================] - 3368s 7s/step - loss: 2.2471 - accuracy: 0.2084 - val_loss: 1.7120 - val_accuracy: 0.3259
# Epoch 2/10
# 450/450 [==============================] - 3342s 7s/step - loss: 1.7875 - accuracy: 0.2825 - val_loss: 1.6499 - val_accuracy: 0.3487
# Epoch 3/10
# 450/450 [==============================] - 3385s 8s/step - loss: 1.6971 - accuracy: 0.3167 - val_loss: 1.6322 - val_accuracy: 0.3564
# Epoch 4/10
# 450/450 [==============================] - ETA: 0s - loss: 1.6657 - accuracy: 0.3398

# %%
history.history.keys()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['loss'])

plt.title('Model Loss and Accuracy Progress During Training')
plt.xlabel('Epoch')
plt.ylabel('Training Accuracy and Loss')
plt.legend(['Training Accuracy', 'Training Loss'])

# %%
plt.plot(history.history['val_loss'])
plt.title('Model Loss During Cross-Validation')
plt.xlabel('Epoch')
plt.ylabel('Validation Loss')
plt.legend(['Validation Loss'])

# %%
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy Progress During Cross-Validation')
plt.xlabel('Epoch')
plt.ylabel('Validation Accuracy')
plt.legend(['Validation Accuracy'])

# %%
test_path=r"Data/data/test"
test_set=ImageDataGenerator(rotation_range=15,
                            rescale=1./255,
                              shear_range=0.2,
                            zoom_range=0.1,
                            width_shift_range=0.1,
                            height_shift_range=0.1)
test_gen=test_set.flow_from_directory(test_path,target_size=(256,256),shuffle=True,class_mode='categorical',batch_size=64)

# %%
evaluate = model.evaluate_generator(test_gen, steps = test_gen.n//64, verbose = 1)

# %%
print('Accuracy during test: {}'.format(evaluate[1]))

# %%
predictions=[]
original=[]
images=[]

for i in range(len(os.listdir(test_path))):
    for item in os.listdir(os.path.join(test_path,str(label_names[i]))):
        image=cv2.imread(os.path.join(test_path,str(label_names[i]),item))
        image=cv2.resize(image,(256,256))
        images.append(image)
        image=image/255
        image=image.reshape((-1,256,256,3))
        predict=model.predict(image)
        predict=np.argmax(predict)
        predictions.append(predict)
        original.append(i)

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
score = accuracy_score(original,predictions)
print("Test Accuracy : {}".format(score))

# %%
L = 5
W = 5

fig, axes = plt.subplots(L, W, figsize = (12, 12))
axes = axes.ravel()

for i in np.arange(0, L*W):
    axes[i].imshow(images[i])
    axes[i].set_title('Guess={}\nTrue={}'.format(str(label_names[predictions[i]]), str(label_names[original[i]])))
    axes[i].axis('off')

plt.subplots_adjust(wspace = 1.2)

# %%
print(classification_report(np.asarray(original), np.asarray(predictions)))

# %%
cm = confusion_matrix(np.asarray(original), np.asarray(predictions))
ax = plt.subplot()
sn.heatmap(cm, annot = True, ax = ax)

ax.set_xlabel('Predicted')
ax.set_ylabel('Original')
